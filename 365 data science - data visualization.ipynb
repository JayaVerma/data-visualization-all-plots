# %% [markdown]
# # Bar charts

# %%
## importing imp libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
df = pd.read_csv("C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 3/3_Bar Chart - Tableau - How to Create a Bar Chart/Course notes/bar_chart_data.csv")

# %%
df
# Out:
#            Brand  Cars Listings
# 0           Audi            419
# 1            BMW            636
# 2  Mercedes-Benz            820
# 3     Mitsubishi            306
# 4        Renault            438
# 5         Toyota            509
# 6     Volkswagen            875

# %%
df.shape
# Out:
# (7, 2)

# %%
plt.figure(figsize=(9,6))
plt.bar(x=df['Brand'], height=df['Cars Listings'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.bar(x=df['Brand'], height=df['Cars Listings'],
       color='midnightblue')
plt.xticks(rotation = 45, fontsize=13)
plt.yticks(fontsize=13)
plt.title('Car Listings by Brands', fontsize=16, fontweight='bold')
plt.ylabel('Number of Listings', fontsize=13)
plt.show()
# plt.savfig('Used car bar.pgn') ## to save the plot as a img in the system

# %% [markdown]
# ## Assignment-bar

# %% [markdown]
# #### Q.1 Your homework task is to use the data set from the section and create a Horizontal Bar Chart. In essence, the information on the chart will remain the same. But you’ll have swapped the x- and y-axis of the chart.

# %%
plt.figure(figsize=(9,6))
plt.barh(y=df['Brand'], width=df['Cars Listings'])
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.barh(y=df['Brand'], width=df['Cars Listings'],
       color='midnightblue')
plt.yticks(fontsize=13)
plt.xticks(fontsize=13)
plt.title('Car Listings by Brands', fontsize=16, fontweight='bold')
plt.xlabel('Number of Listings', fontsize=13)
plt.show()
# plt.savfig('Used car bar.pgn') ## to save the plot as a img in the system

# %% [markdown]
# ### practice test - bar

# %%
dfnew = pd.read_csv('C:/Users/HP/Downloads/grocery_store_items.csv')

# %%
dfnew
# Out:
#        Grocery Items  Units Sold
# 0    Frozen Dinners        23580
# 1     Packaged Meats       78000
# 2  Laundry Detergent       40300
# 3       Salty Snacks       38430
# 4              Bread      123000
# 5           Cereals        19044
# 6               Soda       12034
# 7      Eggs and Milk       45000

# %%
plt.figure(figsize=(14,6))
plt.bar(x=dfnew['Grocery Items'], height=dfnew['Units Sold'],
       color='midnightblue')
# plt.yticks(fontsize=13)
# plt.xticks(fontsize=13)
# plt.title('Car Listings by Brands', fontsize=16, fontweight='bold')
# plt.xlabel('Number of Listings', fontsize=13)
plt.show()

# %%
plt.figure(figsize=(9,6))
plt.barh(y=dfnew['Grocery Items'], width=dfnew['Units Sold'],
       color='midnightblue')
# plt.yticks(fontsize=13)
# plt.xticks(fontsize=13)
# plt.title('Car Listings by Brands', fontsize=16, fontweight='bold')
# plt.xlabel('Number of Listings', fontsize=13)
plt.show()

# %% [markdown]
# # Pie charts
# 1. best suited for displaying data which sums up to 100%

# %%
df_feul_engine_type = pd.read_csv('C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 4/1_Pie Chart - Introduction - General Theory and Dataset/Course notes/pie_chart_data.csv')

# %%
df_feul_engine_type
# Out:
#   Engine Fuel Type  Number of Cars
# 0           Diesel            2019
# 1              Gas             613
# 2            Other             154
# 3           Petrol            1559

# %%
sns.set_palette('colorblind')

# %%
plt.figure(figsize=(10,9))
plt.pie(df_feul_engine_type['Number of Cars'], 
        labels=df_feul_engine_type['Engine Fuel Type'].values,
       autopct='%.2f%%',
       textprops={'size':'x-large', 
                  'fontweight':'bold', 
                  'rotation': '30',
                   'color':'w'})
plt.legend()
plt.title('CAR BY ENGINE FUEL TYPE',fontsize=20, fontweight='bold')
plt.show()

# %% [markdown]
# Why should we not use pie chart?
# 1. when data doesnt sums up to 100% or can say you have wrong type of data
# 2. when their are too many categories
# 3. generally the pie slices are incomprehensive (6-7 max)
# 4. 3D pies are a no no
# 5. never use donut charts
#
# when to use pie charts?
# 1.  when their is less categories
# 2. data sums upto 100%

# %% [markdown]
# # Stacked area chart

# %%
df_fuel_engine_type = pd.read_csv('C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 5/1_Stacked Area Chart - Introduction - General Theory and Dataset/Course notes/stacked_area_chart_data.csv')

# %%
df_fuel_engine_type
# Out:
#     Year    Gas  Petrol  Diesel  Other
# 0   1982      0      94       0      0
# 1   1983      0     347       0      0
# 2   1984    300       0     334      0
# 3   1985   1030    1184     984      0
# 4   1986    511     681    1066    340
# 5   1987   1817    1840     400    940
# 6   1988   2999    1882    2060      1
# 7   1989   2626    1641    1304    330
# 8   1990   1290    3247       1      0
# 9   1991   1566    6776    1063    400
# 10  1992   2358    1925    2824    350
# 11  1993   1231    3375    2302      0
# 12  1994   2386    5691    2569     77
# 13  1995   2373    5115    4563    666
# 14  1996   4264    6792    6996   1235
# 15  1997   7031    7336    7877    370
# 16  1998   5578    7511    8634    310
# 17  1999   4069    6147   16742   1493
# 18  2000   6459   10754   23102    531
# 19  2001   3932    7590   22115   1029
# 20  2002   3375    7069   18144    479
# 21  2003   6032    8518   19605    281
# 22  2004   8332    7978   17400   1821
# ...

# %%
colors = ['#011638', '#7e2987','ef2026']
labels = ['Diesel','Petrol','Gas']
#sns.set_style('white')
plt.figure(figsize=(12,6))
plt.stackplot(df_fuel_engine_type['Year'],
             df_fuel_engine_type['Diesel'],
             df_fuel_engine_type['Petrol'],
             df_fuel_engine_type['Gas'],
             colors = colors,
             edgecolor = 'none')
plt.xticks(df_fuel_engine_type['Year'], rotation=45)
plt.legend(labels = labels, loc='upper left', fontsize=15)
plt.ylabel("Numbers of cars", fontsize=15)
plt.title("POPULARITY OF ENGINE FUEL TYPES(1982-2016)", 
          fontsize=20, fontweight='bold')
sns.despine()
plt.show()

# %% [markdown]
# #### IMP points:-
# 1. Stacked area charts are great for spotting trends, but only work well with a few categories.
# 2. Stacked area charts are used to discover trends and patterns in the data
# 3. follows development of several different variables over time
# 4. y axis of the chart should began with zero

# %% [markdown]
# ### What makes a good area chart?
#
# 1. when we have time date
# 2. when we have to compare volume among the categories
# 3. when we have atleast 3 categories
# 4. when the variables are ordered and numerical
# 5. when we have no more than 6 -7 categories

# %% [markdown]
# # Line charts
#
# 1. Line charts shows evolution of one or several quantities
# 2. Often use to represent time series data
# 3. Stock market returns
#
# Here we not only see the general trends but also concentrate on specific periods

# %%
df_spx_ftse_00_10 = pd.read_csv('C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 6/1_Line Chart - Introduction - General Theory and Dataset/Course notes/line_chart_data.csv')

# %%
df_spx_ftse_00_10
# Out:
#             Date   GSPC500   FTSE100
# 0     03-01-2000  0.003264  0.000000
# 1     04-01-2000 -0.009549  0.000000
# 2     05-01-2000 -0.038345 -0.038137
# 3     06-01-2000  0.001922 -0.019502
# 4     07-01-2000  0.000956 -0.013571
# ...          ...       ...       ...
# 2865  27-12-2010 -0.002282  0.002135
# 2866  28-12-2010  0.003539  0.000000
# 2867  29-12-2010 -0.000254  0.000000
# 2868  30-12-2010  0.000524 -0.002080
# 2869  31-12-2010 -0.002128 -0.004236
#
# [2870 rows x 3 columns]

# %%
df_spx_ftse_00_10['new_date'] = pd.to_datetime(df_spx_ftse_00_10['Date'])

# %%
df_spx_ftse_00_10['new_date']
# Out:
# 0      2000-03-01
# 1      2000-04-01
# 2      2000-05-01
# 3      2000-06-01
# 4      2000-07-01
#           ...
# 2865   2010-12-27
# 2866   2010-12-28
# 2867   2010-12-29
# 2868   2010-12-30
# 2869   2010-12-31
# Name: new_date, Length: 2870, dtype: datetime64[ns]

# %%
df_spx_ftse_00_10
# Out:
#             Date   GSPC500   FTSE100   new_date
# 0     03-01-2000  0.003264  0.000000 2000-03-01
# 1     04-01-2000 -0.009549  0.000000 2000-04-01
# 2     05-01-2000 -0.038345 -0.038137 2000-05-01
# 3     06-01-2000  0.001922 -0.019502 2000-06-01
# 4     07-01-2000  0.000956 -0.013571 2000-07-01
# ...          ...       ...       ...        ...
# 2865  27-12-2010 -0.002282  0.002135 2010-12-27
# 2866  28-12-2010  0.003539  0.000000 2010-12-28
# 2867  29-12-2010 -0.000254  0.000000 2010-12-29
# 2868  30-12-2010  0.000524 -0.002080 2010-12-30
# 2869  31-12-2010 -0.002128 -0.004236 2010-12-31
#
# [2870 rows x 4 columns]

# %%
labels = ['S&P 500', 'FTSE 100']
plt.figure(figsize = (20,8))
plt.plot(df_spx_ftse_00_10['new_date'], df_spx_ftse_00_10['GSPC500'])
plt.plot(df_spx_ftse_00_10['new_date'], df_spx_ftse_00_10['FTSE100'])
plt.title('S&P vs FTSE Returns (2000-2010)', fontsize=14,fontweight='bold')
plt.ylabel('Returns')
plt.xlabel('Date')
plt.legend(labels=labels, fontsize='large')
plt.show()

# %%
df_spx_ftse_H2_08 = df_spx_ftse_00_10[(df_spx_ftse_00_10.new_date>='2008-07-01') &
                                     (df_spx_ftse_00_10.new_date<='2008-12-31')]

# %%
df_spx_ftse_H2_08
# Out:
#             Date   GSPC500   FTSE100   new_date
# 2090  07-01-2008 -0.020734 -0.020202 2008-07-01
# 2091  08-01-2008  0.001160 -0.002016 2008-08-01
# 2092  09-01-2008 -0.017984  0.003283 2008-09-01
# 2093  10-01-2008  0.011890 -0.013183 2008-10-01
# 2094  11-01-2008  0.009333 -0.007971 2008-11-01
# ...          ...       ...       ...        ...
# 2343  25-12-2008  0.000000  0.000000 2008-12-25
# 2344  26-12-2008  0.006529  0.000000 2008-12-26
# 2345  29-12-2008  0.003289  0.000000 2008-12-29
# 2346  30-12-2008 -0.002052  0.024380 2008-12-30
# 2347  31-12-2008  0.022985  0.026578 2008-12-31
#
# [132 rows x 4 columns]

# %%
labels = ['S&P 500', 'FTSE 100']
plt.figure(figsize = (20,8))
plt.plot(df_spx_ftse_H2_08['new_date'], df_spx_ftse_H2_08['GSPC500'])
plt.plot(df_spx_ftse_H2_08['new_date'], df_spx_ftse_H2_08['FTSE100'])
plt.title('S&P vs FTSE Returns (2000-2010)', fontsize=14,fontweight='bold')
plt.ylabel('Returns')
plt.xlabel('Date')
plt.legend(labels=labels, fontsize='large')
plt.show()

# %% [markdown]
# ## what makes a good line chart?
# 1. when displaying time series data
# 2. when we have several differnt variables (3,5 or even 10 differnt variable over time)
# 3. useful when we're interested to see parts of the whole
# 4. supports only the progration of few variables -> stacked area charts
# 5. when we have several categories
# 6. it is not necessory that it starts from zero

# %% [markdown]
# # Histogram
#
# 1. Shows the distribution of a numeric variable
# 2. the variable ranges pf values is split into intervals, represented by different bins
# 3. the heigh of the bins shows the numbers of observations with in an interval
#
# Histograms are one of the easiestt and the most useful tool to undersatand numerical data.

# %%
df_real_estate = pd.read_csv("C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 7/1_Histogram - Introduction - General Theory and Dataset/Course notes/histogram_data.csv")

# %%
df_real_estate
# Out:
#        ID  Building Type  Year of sale  Month of sale Type of property  \
# 0    1030              1        2005.0           11.0        Apartment
# 1    1029              1        2005.0           10.0        Apartment
# 2    2002              2        2007.0            7.0        Apartment
# 3    2031              2        2007.0           12.0        Apartment
# 4    1049              1        2004.0           11.0        Apartment
# ..    ...            ...           ...            ...              ...
# 262  5044              5           NaN            NaN        Apartment
# 263  5047              5           NaN            NaN        Apartment
# 264  5048              5           NaN            NaN        Apartment
# 265  5050              5           NaN            NaN        Apartment
# 266  5051              5           NaN            NaN        Apartment
#
#      Property #  Area (ft.)  Price
# 0            30      743.09    246
# 1            29      756.21    246
# ...

# %%
plt.figure(figsize=(8,6))
plt.hist(df_real_estate["Price"],
        bins =8,
        color = '#108A99')
plt.title('Distribution of real Estate Price', fontsize=15, fontweight='bold')
plt.xlabel("Price in (000' $)")
plt.ylabel("Number of properties")
sns.despine()
plt.show()

# %% [markdown]
# # Scatter plot

# %% [markdown]
# 1. Can display a large number of points
# 2. each observation is a point on that scatter
# 3. Our data is not aggregated
#
# - Can reveal relationships like correlation within the features
# - The concentration of observations and outliers in the data is easily visible
# - A vital part of the exploratory data process for many statistical models

# %%
plt.figure(figsize=(12,8))
scatter = plt.scatter(df_real_estate['Area (ft.)'],
           df_real_estate['Price'],
           alpha=0.6,
           c= df_real_estate['Building Type'],
           cmap = 'viridis')
plt.legend(*scatter.legend_elements(),
          loc = 'upper left',
          title = 'Building Type')
plt.title("Relationship between Area and Price Of Califonia Real Estates",
         fontsize=15,
         weight='bold')
plt.xlabel('Area (sq. ft.)', weight='bold')
plt.ylabel("Price (ooo's of $)", weight='bold')
sns.despine()
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(df_real_estate['Price'],
                df_real_estate['Area (ft.)'],
           hue = df_real_estate['Building Type'],
            palette = ['black', 'darkblue', 'purple', 'pink', 'skyblue'],
           s=100)
plt.title("Relationship between Area and Price Of Califonia Real Estates",
         fontsize=15,
         weight='bold')
plt.xlabel('Area (sq. ft.)', weight='bold')
plt.ylabel("Price (ooo's of $)", weight='bold')
sns.despine()
plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # Regression plot

# %%
df_ad_expenditure = pd.read_csv('C:/Users/HP/Desktop/ML projects/Data_Science_365/Data visualization/Section 9/1_Regression Plot - Introduction - General Theory and Dataset/Course notes/scatter_plot_ii.csv')

# %%
df_ad_expenditure
# Out:
#      Budget  Sales
# 0     337.1   22.1
# 1     128.9   10.4
# 2     132.4    9.3
# 3     251.3   18.5
# 4     250.0   12.9
# ..      ...    ...
# 195    55.7    7.6
# 196   107.2    9.7
# 197   192.7   12.8
# 198   391.8   25.5
# 199   249.4   13.4
#
# [200 rows x 2 columns]

# %%
#plt.figure(figsize=(12,8))
sns.set(rc = {'figure.figsize': (9,6)})
sns.regplot(x = 'Budget',
           y = 'Sales',
           data = df_ad_expenditure,
           scatter_kws = {'color':'k'},
           line_kws = {'color':'red'})
plt.xlabel("Ad Expenditure in (000's $)", fontsize=15)
plt.ylabel("Sales in (000's Units)",fontsize=15)
plt.title("Effect of Expenditure on the sales", fontsize=20, weight= 'bold')
plt.show()

# %%
#plt.figure(figsize=(12,8))
#sns.set(rc = {'figure.figsize': (9,6)})
sns.lmplot(x = 'Budget',
           y = 'Sales',
           data = df_ad_expenditure,
           height =10,
           scatter_kws = {'color':'k'},
           line_kws = {'color':'red'})
plt.xlabel("Ad Expenditure in (000's $)", fontsize=15)
plt.ylabel("Sales in (000's Units)",fontsize=15)
plt.title("Effect of Expenditure on the sales", fontsize=20, weight= 'bold')
plt.show()
